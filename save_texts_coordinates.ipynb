# %%
import os
import cv2
from google.cloud import vision
import boto3
import json
import random

from dotenv import load_dotenv

load_dotenv()

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'lacuentax-adb671932cd7.json'

# %%
s3_client = boto3.client(
  's3',
  aws_access_key_id=os.getenv('aws_access_key_id'),
  aws_secret_access_key=os.getenv('aws_secret_access_key'),
  region_name=os.getenv('region_name')
)

bucket_name = 'la-cuentax'

# %%
def get_texts_coordinates_api(image_cv):
    """
    Consume google vision API to get image texts

    image_cv: cv2/numpy

    return: list of text with coordinates
    """
    client = vision.ImageAnnotatorClient(client_options={'api_endpoint': 'eu-vision.googleapis.com'})
    image_vision = vision.Image(content=cv2.imencode('.jpeg', image_cv)[1].tobytes())
        
    response = client.text_detection(image=image_vision)
    texts = response.text_annotations

    texts_coordinates = []

    for text in texts:
        coordinates = [(vertex.x, vertex.y) for vertex in text.bounding_poly.vertices]

        texts_coordinates.append({
            'text': text.description,
            'coo': coordinates
        })

    return texts_coordinates

# %%
def save_text_coordinates(uid, image_cv):
    """
    Get text coordinates for an image, either from cached pickle file or from API
    
    Args:
        image_path (str): Uid of the image
        image_cv: OpenCV image object
        
    Returns:
        list: Text coordinates data
    """
    # Check if json file exists
    if os.path.exists(f'texts_coordinates/{uid}.json'):
        return True
    
    # If we get here, either file doesn't exist or image_id not in cache
    print(f"Getting new data from API for image {uid}")
    texts_coordinates = get_texts_coordinates_api(image_cv)

    with open(f'texts_coordinates/{uid}.json', 'w') as f:
        json.dump(texts_coordinates[1:], f)
    return True

# %%
def download_image_from_s3(s3_client, bucket_name, s3_key, local_path):
    try:
        # Download the file
        s3_client.download_file(bucket_name, s3_key, local_path)
        print(f"Successfully downloaded {s3_key} to {local_path}")
    except Exception as e:
        print(f"Error downloading file: {e}")

# %%
def save_text_coordinates(uids, s3_client, bucket_name):    
    # Process each UID
    for uid in uids:
        # Define paths
        local_image_path = f'cuentas/{uid}.jpeg'
        s3_key = f'{uid}.jpeg'
        
        # Download image if it doesn't exist locally
        if not os.path.exists(local_image_path):
            print(f"Downloading image for UID: {uid}")
            download_image_from_s3(s3_client, bucket_name, s3_key, local_image_path)
        
        # Process text coordinates if image exists locally
        if os.path.exists(local_image_path):
            image_cv = cv2.imread(local_image_path)
            if image_cv is not None:
                save_text_coordinates(uid, image_cv)
            else:
                print(f"Error: Could not read image for UID: {uid}")
        else:
            print(f"Error: Image not found for UID: {uid}")

# %%
def get_random_jpeg_files_from_s3(s3_client, bucket_name, n, ids_already_saved=None):
    """
    Get n random JPEG files from the specified S3 bucket.

    Args:
        s3_client: Boto3 S3 client
        bucket_name (str): Name of the S3 bucket
        n (int): Number of random JPEG files to retrieve

    Returns:
        list: List of n random JPEG file keys from the S3 bucket
    """
    # List all files in the S3 bucket
    response = s3_client.list_objects_v2(Bucket=bucket_name)
    files = [item['Key'] for item in response.get('Contents', [])]

    # Filter for JPEG files
    jpeg_files = [f for f in files if f.endswith('.jpeg')]

    if ids_already_saved:
        jpeg_files = [f for f in jpeg_files if f.split('.')[0] not in ids_already_saved]

    # Select n random JPEG files
    if len(jpeg_files) < n:
        print(f"Requested {n} files, but only {len(jpeg_files)} JPEG files available. Returning all available files.")
        return jpeg_files
    else:
        return random.sample(jpeg_files, n)

# %%
# Images with OCR results
files = os.listdir('./texts_coordinates')
uids_with_texts_coos = [f.split('.')[0] for f in files]
print('Nb images with OCR res:', len(uids_with_texts_coos))

bad_image = [
    '2720b437-bb67-49fc-a8cd-be1ad6b19322',
    '04bc47b0-6d5e-46e4-8cd6-444da957972b',
    '13d1f973-d1e7-4a58-b572-d396d253e42f',
]

supermarket_image = [
    '22fced9f-f189-4fee-a8d3-b577ddcfafc5',
    '2900fc9e-817a-469e-997a-eb3ddfab6e50',
    '0f7ee436-2254-44ee-af73-fbbe7d245f37',
    '3b4defca-8970-427f-979a-d5120aab2fc5',
    '18752e6d-f814-4329-8f79-409070b84164',
    '3f7b9c7f-7d0c-45de-acf0-ac290e3b2425',
]

files_to_download = get_random_jpeg_files_from_s3(s3_client, bucket_name, 50, uids_with_texts_coos + bad_image + supermarket_image)
uids_to_download = [filename.split('.')[0] for filename in files_to_download]
print(len(uids_to_download))
# Out:
# Nb images with OCR res: 172
# 50

# %%
process_batch_images(uids_to_download, s3_client, bucket_name)
# Out:
# Downloading image for UID: 1894a6ff-a8ce-4477-89a8-dde330d19f6c
# Successfully downloaded 1894a6ff-a8ce-4477-89a8-dde330d19f6c.jpeg to cuentas/1894a6ff-a8ce-4477-89a8-dde330d19f6c.jpeg
# Getting new data from API for image 1894a6ff-a8ce-4477-89a8-dde330d19f6c
# Downloading image for UID: 1b76af5c-a34b-45c6-922c-c98ead5758a5
# Successfully downloaded 1b76af5c-a34b-45c6-922c-c98ead5758a5.jpeg to cuentas/1b76af5c-a34b-45c6-922c-c98ead5758a5.jpeg
# Getting new data from API for image 1b76af5c-a34b-45c6-922c-c98ead5758a5
# Downloading image for UID: 2056c078-18a3-443e-883d-98ae79677298
# Successfully downloaded 2056c078-18a3-443e-883d-98ae79677298.jpeg to cuentas/2056c078-18a3-443e-883d-98ae79677298.jpeg
# Getting new data from API for image 2056c078-18a3-443e-883d-98ae79677298
# Downloading image for UID: 11b9b924-ffff-42e1-bcba-2029993dcc3a
# Successfully downloaded 11b9b924-ffff-42e1-bcba-2029993dcc3a.jpeg to cuentas/11b9b924-ffff-42e1-bcba-2029993dcc3a.jpeg
# Getting new data from API for image 11b9b924-ffff-42e1-bcba-2029993dcc3a
# Downloading image for UID: 22648292-b489-4536-8d31-c1e5b493c77a
# Successfully downloaded 22648292-b489-4536-8d31-c1e5b493c77a.jpeg to cuentas/22648292-b489-4536-8d31-c1e5b493c77a.jpeg
# Getting new data from API for image 22648292-b489-4536-8d31-c1e5b493c77a
# Downloading image for UID: 2c4af2e9-d199-4811-907f-210fce579da5
# Successfully downloaded 2c4af2e9-d199-4811-907f-210fce579da5.jpeg to cuentas/2c4af2e9-d199-4811-907f-210fce579da5.jpeg
# Getting new data from API for image 2c4af2e9-d199-4811-907f-210fce579da5
# Downloading image for UID: 0bafbde4-3cfa-4056-8350-906317c89e68
# Successfully downloaded 0bafbde4-3cfa-4056-8350-906317c89e68.jpeg to cuentas/0bafbde4-3cfa-4056-8350-906317c89e68.jpeg
# Getting new data from API for image 0bafbde4-3cfa-4056-8350-906317c89e68
# Downloading image for UID: 06493bd5-d327-41b9-b73f-f7e5ffecac0d
# Successfully downloaded 06493bd5-d327-41b9-b73f-f7e5ffecac0d.jpeg to cuentas/06493bd5-d327-41b9-b73f-f7e5ffecac0d.jpeg
# Getting new data from API for image 06493bd5-d327-41b9-b73f-f7e5ffecac0d
# Downloading image for UID: 40229ec8-f760-4e56-b5a9-ef3e77fc060e
# Successfully downloaded 40229ec8-f760-4e56-b5a9-ef3e77fc060e.jpeg to cuentas/40229ec8-f760-4e56-b5a9-ef3e77fc060e.jpeg
# Getting new data from API for image 40229ec8-f760-4e56-b5a9-ef3e77fc060e
# Downloading image for UID: 0ebde8b5-137d-42e9-ae57-c8193b99e588
# Successfully downloaded 0ebde8b5-137d-42e9-ae57-c8193b99e588.jpeg to cuentas/0ebde8b5-137d-42e9-ae57-c8193b99e588.jpeg
# Getting new data from API for image 0ebde8b5-137d-42e9-ae57-c8193b99e588
# Downloading image for UID: 2d9b99dc-0913-4a82-a49b-0b00adccb987
# Successfully downloaded 2d9b99dc-0913-4a82-a49b-0b00adccb987.jpeg to cuentas/2d9b99dc-0913-4a82-a49b-0b00adccb987.jpeg
# Getting new data from API for image 2d9b99dc-0913-4a82-a49b-0b00adccb987
# Downloading image for UID: 194c6405-b021-4c25-97ee-62a2b5f81901
# Successfully downloaded 194c6405-b021-4c25-97ee-62a2b5f81901.jpeg to cuentas/194c6405-b021-4c25-97ee-62a2b5f81901.jpeg
# Getting new data from API for image 194c6405-b021-4c25-97ee-62a2b5f81901
# Downloading image for UID: 1018be7d-37cd-44b8-9cb6-d39b1f0889d4
# Successfully downloaded 1018be7d-37cd-44b8-9cb6-d39b1f0889d4.jpeg to cuentas/1018be7d-37cd-44b8-9cb6-d39b1f0889d4.jpeg
# Getting new data from API for image 1018be7d-37cd-44b8-9cb6-d39b1f0889d4
# Downloading image for UID: 2bce1cc9-bbf8-427e-a7df-68360392292c
# Successfully downloaded 2bce1cc9-bbf8-427e-a7df-68360392292c.jpeg to cuentas/2bce1cc9-bbf8-427e-a7df-68360392292c.jpeg
# Getting new data from API for image 2bce1cc9-bbf8-427e-a7df-68360392292c
# Downloading image for UID: 2a51e100-eba5-4084-9e52-9d90e8922941
# Successfully downloaded 2a51e100-eba5-4084-9e52-9d90e8922941.jpeg to cuentas/2a51e100-eba5-4084-9e52-9d90e8922941.jpeg
# Getting new data from API for image 2a51e100-eba5-4084-9e52-9d90e8922941
# Downloading image for UID: 04bc47b0-6d5e-46e4-8cd6-444da957972b
# Successfully downloaded 04bc47b0-6d5e-46e4-8cd6-444da957972b.jpeg to cuentas/04bc47b0-6d5e-46e4-8cd6-444da957972b.jpeg
# Getting new data from API for image 04bc47b0-6d5e-46e4-8cd6-444da957972b
# Downloading image for UID: 032939a7-ba57-4d72-bdcf-464a44c7603d
# Successfully downloaded 032939a7-ba57-4d72-bdcf-464a44c7603d.jpeg to cuentas/032939a7-ba57-4d72-bdcf-464a44c7603d.jpeg
# Getting new data from API for image 032939a7-ba57-4d72-bdcf-464a44c7603d
# Downloading image for UID: 0c355bc3-e66f-417f-8cd8-cfe8c021a5a6
# Successfully downloaded 0c355bc3-e66f-417f-8cd8-cfe8c021a5a6.jpeg to cuentas/0c355bc3-e66f-417f-8cd8-cfe8c021a5a6.jpeg
# Getting new data from API for image 0c355bc3-e66f-417f-8cd8-cfe8c021a5a6
# Downloading image for UID: 10da576c-d383-4d99-ae73-0608853f00de
# Successfully downloaded 10da576c-d383-4d99-ae73-0608853f00de.jpeg to cuentas/10da576c-d383-4d99-ae73-0608853f00de.jpeg
# Getting new data from API for image 10da576c-d383-4d99-ae73-0608853f00de
# Downloading image for UID: 266b1c02-7d9c-4f3a-bb5f-6ac0c8785736
# Successfully downloaded 266b1c02-7d9c-4f3a-bb5f-6ac0c8785736.jpeg to cuentas/266b1c02-7d9c-4f3a-bb5f-6ac0c8785736.jpeg
# Getting new data from API for image 266b1c02-7d9c-4f3a-bb5f-6ac0c8785736
# Downloading image for UID: 3eac0216-815f-47f4-a6ca-9cb52287a30f
# Successfully downloaded 3eac0216-815f-47f4-a6ca-9cb52287a30f.jpeg to cuentas/3eac0216-815f-47f4-a6ca-9cb52287a30f.jpeg
# Getting new data from API for image 3eac0216-815f-47f4-a6ca-9cb52287a30f
# Downloading image for UID: 3f7b9c7f-7d0c-45de-acf0-ac290e3b2425
# Successfully downloaded 3f7b9c7f-7d0c-45de-acf0-ac290e3b2425.jpeg to cuentas/3f7b9c7f-7d0c-45de-acf0-ac290e3b2425.jpeg
# Getting new data from API for image 3f7b9c7f-7d0c-45de-acf0-ac290e3b2425
# Downloading image for UID: 3b4defca-8970-427f-979a-d5120aab2fc5
# Successfully downloaded 3b4defca-8970-427f-979a-d5120aab2fc5.jpeg to cuentas/3b4defca-8970-427f-979a-d5120aab2fc5.jpeg
# Getting new data from API for image 3b4defca-8970-427f-979a-d5120aab2fc5
# Downloading image for UID: 0c065996-4f57-410e-aa2d-0ede2d29c2db
# Successfully downloaded 0c065996-4f57-410e-aa2d-0ede2d29c2db.jpeg to cuentas/0c065996-4f57-410e-aa2d-0ede2d29c2db.jpeg
# Getting new data from API for image 0c065996-4f57-410e-aa2d-0ede2d29c2db
# Downloading image for UID: 14cd2e17-a814-4209-9c78-8ef6eba226c4
# Successfully downloaded 14cd2e17-a814-4209-9c78-8ef6eba226c4.jpeg to cuentas/14cd2e17-a814-4209-9c78-8ef6eba226c4.jpeg
# Getting new data from API for image 14cd2e17-a814-4209-9c78-8ef6eba226c4
# Downloading image for UID: 13d1f973-d1e7-4a58-b572-d396d253e42f
# Successfully downloaded 13d1f973-d1e7-4a58-b572-d396d253e42f.jpeg to cuentas/13d1f973-d1e7-4a58-b572-d396d253e42f.jpeg
# Getting new data from API for image 13d1f973-d1e7-4a58-b572-d396d253e42f
# Downloading image for UID: 0a2a8a70-98b8-4382-98f2-1623c3b28df5
# Successfully downloaded 0a2a8a70-98b8-4382-98f2-1623c3b28df5.jpeg to cuentas/0a2a8a70-98b8-4382-98f2-1623c3b28df5.jpeg
# Getting new data from API for image 0a2a8a70-98b8-4382-98f2-1623c3b28df5
# Downloading image for UID: 3aad2697-ab76-404c-ab60-29eb6a14244c
# Successfully downloaded 3aad2697-ab76-404c-ab60-29eb6a14244c.jpeg to cuentas/3aad2697-ab76-404c-ab60-29eb6a14244c.jpeg
# Getting new data from API for image 3aad2697-ab76-404c-ab60-29eb6a14244c
# Downloading image for UID: 34dcdf20-42f7-4b91-aec8-54cb548ef547
# Successfully downloaded 34dcdf20-42f7-4b91-aec8-54cb548ef547.jpeg to cuentas/34dcdf20-42f7-4b91-aec8-54cb548ef547.jpeg
# Getting new data from API for image 34dcdf20-42f7-4b91-aec8-54cb548ef547
# Downloading image for UID: 074af943-ffe7-46cc-b35f-c423c4c2ec6e
# Successfully downloaded 074af943-ffe7-46cc-b35f-c423c4c2ec6e.jpeg to cuentas/074af943-ffe7-46cc-b35f-c423c4c2ec6e.jpeg
# Getting new data from API for image 074af943-ffe7-46cc-b35f-c423c4c2ec6e
# Downloading image for UID: 19462611-a3c4-440b-8e03-aa1f28609c68
# Successfully downloaded 19462611-a3c4-440b-8e03-aa1f28609c68.jpeg to cuentas/19462611-a3c4-440b-8e03-aa1f28609c68.jpeg
# Getting new data from API for image 19462611-a3c4-440b-8e03-aa1f28609c68
# Downloading image for UID: 21d94b55-d6b0-4733-8891-d514a3f00174
# Successfully downloaded 21d94b55-d6b0-4733-8891-d514a3f00174.jpeg to cuentas/21d94b55-d6b0-4733-8891-d514a3f00174.jpeg
# Getting new data from API for image 21d94b55-d6b0-4733-8891-d514a3f00174
# Downloading image for UID: 29119a88-44af-499e-a2f5-926ee14d84af
# Successfully downloaded 29119a88-44af-499e-a2f5-926ee14d84af.jpeg to cuentas/29119a88-44af-499e-a2f5-926ee14d84af.jpeg
# Getting new data from API for image 29119a88-44af-499e-a2f5-926ee14d84af
# Downloading image for UID: 34e3939d-855e-4e83-9936-9402b954c7c6
# Successfully downloaded 34e3939d-855e-4e83-9936-9402b954c7c6.jpeg to cuentas/34e3939d-855e-4e83-9936-9402b954c7c6.jpeg
# Getting new data from API for image 34e3939d-855e-4e83-9936-9402b954c7c6
# Downloading image for UID: 1d748209-9eb8-46a3-a178-6d4e1619c40a
# Successfully downloaded 1d748209-9eb8-46a3-a178-6d4e1619c40a.jpeg to cuentas/1d748209-9eb8-46a3-a178-6d4e1619c40a.jpeg
# Getting new data from API for image 1d748209-9eb8-46a3-a178-6d4e1619c40a
# Downloading image for UID: 0632e7ba-d7e4-4bb8-9c2a-f7bfbe84942b
# Successfully downloaded 0632e7ba-d7e4-4bb8-9c2a-f7bfbe84942b.jpeg to cuentas/0632e7ba-d7e4-4bb8-9c2a-f7bfbe84942b.jpeg
# Getting new data from API for image 0632e7ba-d7e4-4bb8-9c2a-f7bfbe84942b
# Downloading image for UID: 0eb790f7-4048-4665-9dcd-aca94af1abe5
# Successfully downloaded 0eb790f7-4048-4665-9dcd-aca94af1abe5.jpeg to cuentas/0eb790f7-4048-4665-9dcd-aca94af1abe5.jpeg
# Getting new data from API for image 0eb790f7-4048-4665-9dcd-aca94af1abe5
# Downloading image for UID: 36d01eb3-b976-4b28-b4b0-d60727768002
# Successfully downloaded 36d01eb3-b976-4b28-b4b0-d60727768002.jpeg to cuentas/36d01eb3-b976-4b28-b4b0-d60727768002.jpeg
# Getting new data from API for image 36d01eb3-b976-4b28-b4b0-d60727768002
# Downloading image for UID: 2171b638-8d25-4f63-aeee-edf0a7291a5d
# Successfully downloaded 2171b638-8d25-4f63-aeee-edf0a7291a5d.jpeg to cuentas/2171b638-8d25-4f63-aeee-edf0a7291a5d.jpeg
# Getting new data from API for image 2171b638-8d25-4f63-aeee-edf0a7291a5d
# Downloading image for UID: 220cec45-cdf7-4de0-bf71-5ddee11fe28a
# Successfully downloaded 220cec45-cdf7-4de0-bf71-5ddee11fe28a.jpeg to cuentas/220cec45-cdf7-4de0-bf71-5ddee11fe28a.jpeg
# Getting new data from API for image 220cec45-cdf7-4de0-bf71-5ddee11fe28a
# Downloading image for UID: 2900fc9e-817a-469e-997a-eb3ddfab6e50
# Successfully downloaded 2900fc9e-817a-469e-997a-eb3ddfab6e50.jpeg to cuentas/2900fc9e-817a-469e-997a-eb3ddfab6e50.jpeg
# Getting new data from API for image 2900fc9e-817a-469e-997a-eb3ddfab6e50
# Downloading image for UID: 2b5cc5aa-bc98-4283-8803-0674d6690e42
# Successfully downloaded 2b5cc5aa-bc98-4283-8803-0674d6690e42.jpeg to cuentas/2b5cc5aa-bc98-4283-8803-0674d6690e42.jpeg
# Getting new data from API for image 2b5cc5aa-bc98-4283-8803-0674d6690e42
# Downloading image for UID: 258bf0a1-4a0d-4131-af68-b56ef6f9c7ec
# Successfully downloaded 258bf0a1-4a0d-4131-af68-b56ef6f9c7ec.jpeg to cuentas/258bf0a1-4a0d-4131-af68-b56ef6f9c7ec.jpeg
# Getting new data from API for image 258bf0a1-4a0d-4131-af68-b56ef6f9c7ec
# Downloading image for UID: 18752e6d-f814-4329-8f79-409070b84164
# Successfully downloaded 18752e6d-f814-4329-8f79-409070b84164.jpeg to cuentas/18752e6d-f814-4329-8f79-409070b84164.jpeg
# Getting new data from API for image 18752e6d-f814-4329-8f79-409070b84164
# Downloading image for UID: 126d3470-e2de-4f73-8459-e908dac7acd9
# Successfully downloaded 126d3470-e2de-4f73-8459-e908dac7acd9.jpeg to cuentas/126d3470-e2de-4f73-8459-e908dac7acd9.jpeg
# Getting new data from API for image 126d3470-e2de-4f73-8459-e908dac7acd9
# Downloading image for UID: 2eb341e0-dd4e-472c-8ac8-04c3380d3833
# Successfully downloaded 2eb341e0-dd4e-472c-8ac8-04c3380d3833.jpeg to cuentas/2eb341e0-dd4e-472c-8ac8-04c3380d3833.jpeg
# Getting new data from API for image 2eb341e0-dd4e-472c-8ac8-04c3380d3833
# Downloading image for UID: 3b268111-3478-4ee7-9cf1-3e798724921b
# Successfully downloaded 3b268111-3478-4ee7-9cf1-3e798724921b.jpeg to cuentas/3b268111-3478-4ee7-9cf1-3e798724921b.jpeg
# Getting new data from API for image 3b268111-3478-4ee7-9cf1-3e798724921b
# Downloading image for UID: 0aaee89f-3443-41a6-8181-bef9d5b93a1d
# Successfully downloaded 0aaee89f-3443-41a6-8181-bef9d5b93a1d.jpeg to cuentas/0aaee89f-3443-41a6-8181-bef9d5b93a1d.jpeg
# Getting new data from API for image 0aaee89f-3443-41a6-8181-bef9d5b93a1d
# Downloading image for UID: 0a92dd6c-e259-45e8-b759-e6fffcb6a6aa
# Successfully downloaded 0a92dd6c-e259-45e8-b759-e6fffcb6a6aa.jpeg to cuentas/0a92dd6c-e259-45e8-b759-e6fffcb6a6aa.jpeg
# Getting new data from API for image 0a92dd6c-e259-45e8-b759-e6fffcb6a6aa
# Downloading image for UID: 0f7ee436-2254-44ee-af73-fbbe7d245f37
# Successfully downloaded 0f7ee436-2254-44ee-af73-fbbe7d245f37.jpeg to cuentas/0f7ee436-2254-44ee-af73-fbbe7d245f37.jpeg
# Getting new data from API for image 0f7ee436-2254-44ee-af73-fbbe7d245f37
